# %%
import albumentations as A
from albumentations.core.transforms_interface import ImageOnlyTransform,DualTransform
from tqdm import tqdm
# import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
import cv2
af = A.Affine(shear=(-45,45),p=1)
per = A.Perspective(p=1)
pa = A.PiecewiseAffine(p=1)
img = cv2.imread("./train_source_image/TRAIN_SOURCE_0000.png")
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

plt.imshow(img)

# %%
import matplotlib.pyplot as plt
plt.imshow(af(image=img)['image'])

# %%
import matplotlib.pyplot as plt
plt.imshow(per(image=img)['image'])

# %%
import matplotlib.pyplot as plt
plt.imshow(pa(image=img)['image'])

# %%
import matplotlib.pyplot as plt
pa = A.ElasticTransform(p=1,alpha=1,alpha_affine=50,sigma=0,interpolation=cv2.INTER_NEAREST,same_dxdy=True)
plt.imshow(pa(image=img)['image'])

# %%
import matplotlib.pyplot as plt

pa = A.Affine(p=1,shear=0,rotate=None)
plt.imshow(pa(image=img)['image'])

# %%
import matplotlib.pyplot as plt

refer = cv2.imread('./test_image/TEST_0004.png')
pa = A.domain_adaptation.HistogramMatching([refer],p=1,read_fn=lambda x:x)
plt.subplot(1,2,1)
plt.imshow(pa(image=img)['image'])
plt.subplot(1,2,2)
plt.imshow(refer)

# %%
import matplotlib.pyplot as plt

refer = cv2.imread('./test_image/TEST_0009.png')
refer = cv2.cvtColor(refer,cv2.COLOR_BGR2RGB)
pa = A.domain_adaptation.PixelDistributionAdaptation([refer],p=1,read_fn=lambda x:x)
plt.subplot(1,2,1)
plt.imshow(pa(image=img)['image'])
plt.subplot(1,2,2)
plt.imshow(refer)
